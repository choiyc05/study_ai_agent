# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in C:\Users\hi\AppData\Local\Programs\Python\Python311\Lib\site-packages (4.1.1)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in C:\Users\hi\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pyspark) (0.10.9.9)

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("PySpark WordCount Test").master("spark://LOCALHOST:7077").getOrCreate()

# %%
print("Spark Version: ", spark.version)
# Out:
# Spark Version:  4.1.1
